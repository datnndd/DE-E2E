# %%
# %sql
CREATE CATALOG IF NOT EXISTS de_e2e;
CREATE SCHEMA IF NOT EXISTS de_e2e.bronze;
CREATE SCHEMA IF NOT EXISTS de_e2e.silver;
CREATE SCHEMA IF NOT EXISTS de_e2e.gold;

# %%
#test read from s3
json_file_test = "s3://de-e2e-413612133697-ap-southeast-1-an/lakehouse/landing/douyin/api_raw/json/niche=douyin_food_restaurant/account_id=food_creator_001/year=2026/month=06/day=14/20260614T142701488865.json"

df_test = spark.read.json(json_file_test)
display(df_test)
